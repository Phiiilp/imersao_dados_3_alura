# %% [markdown]
# <a href="https://colab.research.google.com/github/Phiiilp/imersao_dados_3_alura/blob/main/Imersao_Dados_aula05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados = pd.read_csv(url_dados, compression = "zip")
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts().plot.pie(label='',labels=['Com droga','Com controle'],radius=1,title="Tratamento")

# %%
dados['tempo'].value_counts().plot.bar(title='Horas gastar nos experimentos').set_xlabel('Horas')
dados['tempo'].value_counts().plot.bar(title='Horas gastar nos experimentos').set_ylabel("Experimentos")
# Out:
# Text(0, 0.5, 'Experimentos')

# %%
dados.columns = dados.columns.str.replace('-','')
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.query('g1 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 5      id_001762a82     com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23804  id_fff506720     com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
mapa = {'droga': 'compostos'}
dados.rename(columns=mapa, inplace=True)
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
cod_compostos = dados['compostos'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('compostos in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
sns.set()
plt.figure(figsize=(11,9))
ax = sns.countplot(x='compostos',data=dados.query('compostos in @cod_compostos'), order=cod_compostos) 
ax.set_title('Top 5 compostos', fontsize= 35)
ax.set_xlabel('Compostos', fontsize=20)
ax.set_ylabel('Quantidade',fontsize=20)
plt.show()

# %%
plt.figure(figsize=[11,9])
ax = sns.histplot(data=dados, x='g0', element="poly")
ax.set_ylabel('Quantidade',fontsize=20)
ax.set_xlabel('g0',fontsize=20)
plt.show()

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados['c1'].describe()
# Out:
# count    23814.000000
# mean        -0.455359
# std          2.004962
# min        -10.000000
# 25%         -0.538425
# 50%          0.009800
# 75%          0.476875
# max          3.915000
# Name: c1, dtype: float64

# %%
dados['compostos'].describe()
# Out:
# count         23814
# unique         3289
# top       cacb2b860
# freq           1866
# Name: compostos, dtype: object

# %%
dados_g = dados.loc[:,'g0':'g771'].describe().T['mean']

plt.figure(figsize=[11,9])
ax = sns.histplot(data=dados_g)
ax.set_title('Media dos Gs',fontsize=30)
ax.set_xlabel('Media',fontsize=20)
ax.set_ylabel('Quantidade',fontsize=20)
plt.show()

# %%
sns.boxplot(x='g1',y='tratamento',data=dados)

# %%
plt.figure(figsize=[11,9])
ax = sns.boxplot(y='g0',x='tempo',data=dados)
ax.set_title('Diferença de tempo entre os valores de g0', fontsize=25)
ax.set_xlabel('Horas', fontsize=15)
ax.set_ylabel('g0', fontsize=15)
plt.show()

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
dados.melt(id_vars=['tratamento','dose','tempo'], value_vars=['g0']).head()
# Out:
#   tratamento dose  tempo variable   value
# 0  com_droga   D1     24       g0  1.0620
# 1  com_droga   D1     72       g0  0.0743
# 2  com_droga   D1     48       g0  0.6280
# 3  com_droga   D1     48       g0 -0.5138
# 4  com_droga   D2     72       g0 -0.3254

# %%
dados.groupby(by=['tratamento','dose','tempo']).mean()
# Out:
#                                g0        g1  ...       c98       c99
# tratamento   dose tempo                      ...
# com_controle D1   24    -0.251760 -0.453322  ...  0.350566  0.342308
#                   48    -0.122773 -0.453638  ...  0.408657  0.450673
#                   72    -0.295271 -0.669059  ...  0.379652  0.319684
#              D2   24     0.010754 -0.229451  ...  0.134107  0.112021
#                   48     0.013174  0.001737  ...  0.232461  0.169539
#                   72     0.070250  0.133537  ...  0.200942  0.165440
# com_droga    D1   24     0.367996 -0.170839  ... -0.340809 -0.216371
#                   48     0.412469 -0.142581  ... -0.634006 -0.389838
#                   72     0.286250 -0.127878  ... -0.835132 -0.588545
#              D2   24     0.115253 -0.081764  ... -0.254499 -0.187848
#                   48     0.214480 -0.001143  ... -0.485368 -0.317882
#                   72     0.253439  0.052840  ... -0.644784 -0.391018
#
# ...

# %%
sns.scatterplot(x='g0', y='g3', data=dados)

# %%
sns.scatterplot(x='g0', y='g8', data=dados)

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento')

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g0':'g50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr = dados.loc[:,'g0':'c99'].corr()

# %%
corr_loc = corr.loc['g0':'g50','c0':'c50']
corr_loc
# Out:
#            c0        c1        c2  ...       c48       c49       c50
# g0  -0.624116 -0.624810 -0.639789  ... -0.595291 -0.609109 -0.594011
# g1  -0.037405 -0.030558 -0.039616  ... -0.006228  0.027230  0.017267
# g2  -0.168656 -0.178692 -0.176733  ... -0.160305 -0.167884 -0.153191
# g3  -0.037342 -0.093505 -0.085298  ... -0.058527 -0.033818 -0.012714
# g4  -0.403545 -0.379840 -0.392841  ... -0.349730 -0.349804 -0.360544
# g5   0.209358  0.198890  0.211988  ...  0.193371  0.192872  0.194516
# g6  -0.103316 -0.079528 -0.078782  ... -0.050473 -0.086187 -0.078581
# g7   0.486478  0.553859  0.565002  ...  0.559356  0.531681  0.516563
# g8   0.621422  0.601678  0.597372  ...  0.513047  0.560689  0.547889
# g9   0.435235  0.475424  0.488331  ...  0.463612  0.458629  0.451328
# g10  0.586035  0.643461  0.640281  ...  0.598668  0.598015  0.592971
# g11 -0.231425 -0.270409 -0.276064  ... -0.254556 -0.229148 -0.226246
# g12  0.345752  0.361244  0.357949  ...  0.340069  0.346491  0.354359
# ...

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_loc, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_loc, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #Alura 4

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.drop(['id'], axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['n_moa']
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Name: n_moa, Length: 23814, dtype: int64

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados['ativo_moa']
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: ativo_moa, Length: 23814, dtype: bool

# %%
contagem_moa.filter(like='inhibitor').head(10)
# Out:
# nfkb_inhibitor              832
# proteasome_inhibitor        726
# cyclooxygenase_inhibitor    435
# dna_inhibitor               402
# cdk_inhibitor               340
# egfr_inhibitor              336
# tubulin_inhibitor           316
# pdgfr_inhibitor             297
# hmgcr_inhibitor             283
# flt3_inhibitor              279
# dtype: int64

# %%
contagem_moa.filter(like='antagonist').head(10)
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# histamine_receptor_antagonist        241
# gaba_receptor_antagonist             165
# cc_chemokine_receptor_antagonist     102
# potassium_channel_antagonist          98
# adenosine_receptor_antagonist         96
# dtype: int64

# %%
contagem_moa.filter(like='_agonist').head(10)
# Out:
# adrenergic_receptor_agonist        270
# glucocorticoid_receptor_agonist    266
# serotonin_receptor_agonist         236
# acetylcholine_receptor_agonist     190
# estrogen_receptor_agonist          158
# dopamine_receptor_agonist          121
# progesterone_receptor_agonist      119
# ppar_receptor_agonist              115
# gaba_receptor_agonist              106
# glutamate_receptor_agonist          74
# dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados_resultados[['id', 'n_moa', 'ativo_moa']], dados, on='id')
dados_combinados.head()
# Out:
#              id  n_moa  ativo_moa tratamento  ...     c96     c97     c98     c99
# 0  id_000644bb2      1       True  com_droga  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc      0      False  com_droga  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a      3       True  com_droga  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391      0      False  com_droga  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3      1       True  com_droga  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 879 columns]

# %%
#dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
#dados_combinados.tail()

# %%
#dados_combinados['eh_24h'] = (dados_combinados['tempo'] == 24)
#dados_combinados['eh_48h'] = (dados_combinados['tempo'] == 48)
#dados_combinados['eh_72h'] = (dados_combinados['tempo'] == 72)
dados_combinados.tail()
# Out:
#                  id  n_moa  ativo_moa  ...     c97     c98     c99
# 23809  id_fffb1ceed      1       True  ...  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c      1       True  ... -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4      0      False  ...  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c      1       True  ...  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b      0      False  ... -0.4775 -2.1500 -4.2520
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
compostos_principais = dados_combinados['compostos'].value_counts().index[0:3]
compostos_principais
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77'], dtype='object')

# %%
plt.figure(figsize=[12,8])

sns.boxplot(data = dados_combinados.query('compostos in @compostos_principais & tempo == 24'), y='g0', x='compostos',
                                        hue='ativo_moa', order=compostos_principais)

plt.show()

# %%
sns.boxplot(data = dados_combinados.query('compostos in @compostos_principais & dose == "D1"'), y='g0', x='compostos',
                                        hue='ativo_moa', order=compostos_principais)

plt.show()

# %%
compostos_principal = dados_combinados['compostos'].value_counts().index[:5]

plt.figure(figsize=[12,8])
sns.boxplot(data= dados_combinados.query('compostos in @compostos_principal'), y='g0', x='compostos', hue='ativo_moa')

# %% [markdown]
# #Aula 5

# %%
dados_combinados.head()
# Out:
#              id  n_moa  ativo_moa tratamento  ...     c96     c97     c98     c99
# 0  id_000644bb2      1       True  com_droga  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc      0      False  com_droga  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a      3       True  com_droga  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391      0      False  com_droga  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3      1       True  com_droga  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 879 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)

modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6170480789418433

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)

accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier




x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

modelo_tree = DecisionTreeClassifier(max_depth=3)
modelo_tree.fit(x_treino, y_treino)
modelo_tree.score(x_teste, y_teste)
# Out:
# 0.6117992861641822

# %%
from sklearn import tree

fig, ax= plt.subplots(figsize=[15,10], facecolor='k')
tree.plot_tree(modelo_tree,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

teste = []
treino = []
for i in range(1,15):
  modelo_tree = DecisionTreeClassifier(max_depth=i)
  modelo_tree.fit(x_treino, y_treino)
  teste.append(modelo_tree.score(x_teste, y_teste))
  treino.append(modelo_tree.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6117992861641822,
#  0.6243963888305689,
#  0.6260760025194205,
#  0.6246063405416754,
#  0.6290153264749108,
#  0.6271257610749528,
#  0.6225068234306109,
#  0.6210371614528658,
#  0.6195674994751207,
#  0.6090699139197985,
#  0.6046609279865631,
#  0.5895444047868991]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6216996483124245,
#  0.6350322817699858,
#  0.6416985984987664,
#  0.6495722009343342,
#  0.661540076636397,
#  0.6743478032649205,
#  0.6873654926250591,
#  0.7038475670568474,
#  0.7226392315364023,
#  0.741220933284342,
#  0.7597501443493779,
#  0.7779119206340874]

# %%
sns.lineplot(x= range(1,15), y = teste, label = 'teste')
sns.lineplot(x= range(1,15), y = treino, label = 'treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento','dose','tempo'])
# Out:
#                  id  n_moa  ativo_moa  ... tempo_24  tempo_48  tempo_72
# 0      id_000644bb2      1       True  ...        1         0         0
# 1      id_000779bfc      0      False  ...        0         0         1
# 2      id_000a6266a      3       True  ...        0         1         0
# 3      id_0015fd391      0      False  ...        0         1         0
# 4      id_001626bd3      1       True  ...        0         0         1
# ...             ...    ...        ...  ...      ...       ...       ...
# 23809  id_fffb1ceed      1       True  ...        1         0         0
# 23810  id_fffb70c0c      1       True  ...        1         0         0
# 23811  id_fffc1c3f4      0      False  ...        0         1         0
# 23812  id_fffcb9e7c      1       True  ...        1         0         0
# 23813  id_ffffdd77b      0      False  ...        0         0         1
#
# [23814 rows x 883 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id','n_moa','ativo_moa','compostos'], axis=1)
x = pd.get_dummies(x, columns=['tratamento','dose','tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

modelo_forest = RandomForestClassifier()
modelo_forest.fit(x_treino, y_treino)
modelo_forest.score(x_teste, y_teste)
# Out:
# 0.6850724333403317

# %%
from sklearn.neighbors import KNeighborsClassifier

numero_de_neighbors = 5
clf = KNeighborsClassifier(numero_de_neighbors)
clf.fit(x_treino, y_treino)
clf.score(x_teste, y_teste)
# Out:
# 0.6953600671845476

# %%
x = dados_combinados.loc[:,'g0':'c99']
y = dados_combinados['tempo'].map({24:0,48:1,72:2})
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)

modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6857022884736511

# %%
modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)

accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.3464203233256351

# %%
dt_temporario = dados_combinados.query('compostos in ["cacb2b860", "87d714366"]')
x = dt_temporario.loc[:,'g0':'g50']
y = dt_temporario['compostos'].map({'cacb2b860': 0, '87d714366': 1})
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)

modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 1.0

# %%
modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)

accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.7214700193423598

# %% [markdown]
# #Alura
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
# R: Pois um tratamento controlado utilizar apenas uma droga
#
# ###DEsafio 02: Plotar as 5 últimas linhas da tabela
# R: dados.tail()
#
# ###Desafio 03: Proporção das classes tratamento.
# R: utilizando o parâmetro normalize = True
#
# ###Desafio 04: Quantas tipos de drogas foram investigados.
# R: 3289
#
# ###Desafio 05: Procurar na documentação o método query(pandas).
# R: dados.query('g0 > 0') Link da documentaçao [aqui](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html?highlight=query#pandas.DataFrame.query)
#
# ###Desafio 06: Renomear as colunas tirando o hífen.
# R: dados.columns = dados.columns.str.replace('-','')
#
# ###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
# R: dados['tempo'].value_counts().plot.bar(title='Horas gastar nos experimentos')
# .set_xlabel('Horas')
# dados['tempo'].value_counts().plot.bar(title='Horas gastar nos experimentos').set_ylabel("Experimentos")
#
# ###Desafio 08: Resumo do que você aprendeu com os dados
# R: biblioteca pandas, e analizar dados usando python.
#
# #Aula2
# ###Desafio 01: Ordenar o gráfico countplot
# R: order=cod_compostos
#
# ###Desafio 02: Melhorar a visualização alterando tamanho da fonte...
# R: ax.set_ylabel('Quantidade',fontsize=20)
#    ax.set_xlabel('g0',fontsize=20)
#
# ###Desafio 03: Plotar os histogramas com seaborn
# R:
# plt.figure(figsize=[11,9])
# ax = sns.histplot(data=dados, x='g0', element="poly")
# ax.set_ylabel('Quantidade',fontsize=20)
# ax.set_xlabel('g0',fontsize=20)
# plt.show()
#
# ###Desafio 04: Estudar sobre as estatíticas retornadas no .describe()
# R: O describe() além de nos informar a média, o tamanho, a porcentagens etc… nos retorna valores diferentes quando os dados são objetos como sua quantidade total,a quantidade de objetos únicos, o objeto com maior quantidade e a sua frequência.
#
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.
# R: Gráficos precisam ser claros e diretos pois pretendem informar os dados fornecidos de maneira organizada e de fácil visão.
#
# ###Desafio 06: Fazer outras análises com o boxplot e até com o histograma.
# R:
# plt.figure(figsize=[11,9])
# ax = sns.boxplot(y='g0',x='tempo',data=dados)
# ax.set_title('Diferença de tempo entre os valores de g0', fontsize=25)
# ax.set_xlabel('Horas', fontsize=15)
# ax.set_ylabel('g0', fontsize=15)
# plt.show()
#
# ###Desafio 07: Resumo do que você aprendeu com os dados
# R: A biblioteca seaborn, a importancia de um gráfico limpo e claro, a analisar dados com o gráfico Histograma e o Diagrama de caixa e usar o describe() para obter uma forma detalhada dos dados com suas médias e valores máximos.
#
# #Aula 03
# ###Desafio 01: Criar tabelas de frequência com pandas.groupby()
# R: dados.groupby(by=['tratamento','dose','tempo']).mean()
#
# ###Desafio 02: Normalizar o crosstab pela coluna.
# R: normalize='columns'
#
# ###Desafio 03: Explorar outros agregadores.
# R: aggfunc='min'/'max'
#
# ###Desafio 04: Explorar o melt.
# R: dados.melt(id_vars=['tratamento','dose','tempo'], value_vars=['g0']).head()
#
# ###Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.
# R: Pelo que eu entendir um gene afeta da mesma forma em todas as celulas.
#
# ###Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)
# R:
#
# Usa a biblioteca numpy para gera um array onde vão fica os dados.
#
# mask = np.triu(np.ones_like(corr_loc, dtype=bool))
#
# Define o tamanho do gráfico.
#
# f, ax = plt.subplots(figsize=(11, 9))
#
# Define as cores do gráfico.
#
# cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Usa a biblioteca seaborn para gerar o gráfico.
#
# sns.heatmap(corr_loc, mask=mask, cmap=cmap, center=0,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})
#
# ###Desafio 07: Resumo do que você aprendeu com os dados
# R: Nessa aula aprendi crosstab/groupby/melt para comparar dados, o uso do correlação e que não necessariamente essas correlações são a razão de algo e a plota a matriz de correlação do seaborn.
#
# #Aula 04
#
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)
# R: contagem_moa.filter(like='inibidor').head(10)
#
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle
# R: dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
#
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
# R:
# dados_combinados['eh_24h'] = (dados_combinados['tempo'] == 24)
# dados_combinados['eh_48h'] = (dados_combinados['tempo'] == 48)
# dados_combinados['eh_72h'] = (dados_combinados['tempo'] == 72)
#
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)
# R:
# sns.boxplot(data = dados_combinados.query('compostos in @compostos_principais & tempo == 24'), y='g0', x='compostos',
#                                         hue='ativo_moa', order=compostos_principais)
#
# sns.boxplot(data = dados_combinados.query('compostos in @compostos_principais & dose == "D1"'), y='g0', x='compostos',
#                                         hue='ativo_moa', order=compostos_principais)
#
#
# ###Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA
# R: Quando um composto realiza a ativação essa ativação já aparece em cada uma das fases e quando nenhum ativa mesmo se mudar para números de horas e doses diferentes.
#
# ###Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes
# R: As configurações dos experimentos não influenciam nos mecanimos ativos pelos compostos.
#
# ###Desafio 08: Resumo do que você aprendeu com os dados
# R: Exploramos outra base de dados, quais mecanimos mais ativados, a juntar a base de dados com o merge e criamos um boxplot para combarar os dados.
#
# #Aula 05
#
# ###Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.
# R: from sklearn.neighbors import KNeighborsClassifier
#
# numero_de_neighbors = 5
# clf = KNeighborsClassifier(numero_de_neighbors)
# clf.fit(x_treino, y_treino)
# clf.score(x_teste, y_teste)
#
# ###Desafio 02: Estude a documentação do Sklearn.
# R: https://scikit-learn.org/stable/
#
# ###Desafio 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo' choosing the right estimator
# R: https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
#
# ###Desafio 04: Teste outras problemas (perguntas). 0, 1 ou +.
# R: x = dados_combinados.loc[:,'g0':'c99']
# y = dados_combinados['tempo'].map({24:0,48:1,72:2})
# x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)
#
# modelo_rlogistica = LogisticRegression(max_iter=1000)
# modelo_rlogistica.fit(x_treino, y_treino)
#
# modelo_rlogistica.score(x_teste, y_teste)
#
# ###Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.
# R: dt_temporario = dados_combinados.query('compostos in ["cacb2b860", "87d714366"]')
# x = dt_temporario.loc[:,'g0':'g50']
# y = dt_temporario['compostos'].map({'cacb2b860': 0, '87d714366': 1})
# x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=452902)
#
# modelo_rlogistica = LogisticRegression(max_iter=1000)
# modelo_rlogistica.fit(x_treino, y_treino)
#
# modelo_rlogistica.score(x_teste, y_teste)
#
# ###Desafio 06: Resumo do que você aprendeu com os dados
# R: O Que é machine learning, os tipos de problemas que podemos usa o machine learning para resolvê-lo, a criar um classificador ingênuo para obter um parâmetro de comparação, o que é uma árvore de decisão e treina um modelo de logística, aprofundar a árvore de decisão e treinar um modelo de Random Forest.
